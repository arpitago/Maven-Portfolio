# %% [markdown]
# **<center> <span style="color:#432371;font-family:serif; font-size:34px;"> TELECOM COMPANY CUSTOMER CHURN ANALYSIS  </span> </center>**

# %% [markdown]
# <style>
# img
# {
#     display:block;
#     float:none;
#     margin-left:auto;
#     margin-right:auto;
#     width:80%;
# }
# </style>

# %% [markdown]
# <center><span style="font-family:Palatino; font-size:22px;"><i> Did you know that attracting a new customer costs <span style="color:#DC143C;">five times</span> as much as keeping an existing one?</i></span> </center>

# %% [markdown]
# ![image.jpg](attachment:8150b7aa-1d17-4b01-adfe-1a7b9b54f9ac.jpg)

# %% [markdown]
# # <span style="font-family:serif; font-size:28px;"> Content</span>
#
# 1. [Introduction](#1)
#     * [What is Customer Churn?](#2)
#     * [How can customer churn be reducded?](#3)
#     * [Objectives](#4)
# 2. [Loading libraries and data](#5)
# 3. [Undertanding the data](#6)
# 4. [Visualize missing values](#7)
# 5. [Data Manipulation](#8)
# 6. [Data Visualization](#9)
# 7. [Conclusion](#10)

# %% [markdown]
# <a id = "1" ></a>
# # <span style="font-family:serif; font-size:28px;"> 1. Introduction</span>
# <a id = "introduction" ></a>

# %% [markdown]
# <a id = "2" ></a>
# #### <b>What is Customer Churn?</b>
# <span style="font-size:16px;">  Customer churn is defined as when customers or subscribers discontinue doing business with a firm or service. </span>
#
# <span style="font-size:16px;"> Customers in the telecom industry can choose from a variety of service providers and actively switch from one to the next. The telecommunications business has an annual churn rate of 15-25 percent in this highly competitive market.</span>
#
# <span style="font-size:16px;"> Individualized customer retention is tough because most firms have a large number of customers and can't afford to devote much time to each of them. The costs would be too great, outweighing the additional revenue. However, if a corporation could forecast which customers are likely to leave ahead of time, it could focus customer retention efforts only on these "high risk" clients. The ultimate goal is to expand its coverage area and retrieve more
# customers loyalty. The core to succeed in this market lies in the customer itself.
# </span>
#
# <span style="font-size:16px;"> Customer churn is a critical metric because it is much less expensive to retain existing customers than it is to acquire new customers.</span>
#
# <a id="churn"></a>
# <a id = "3" ></a>
#
# <span style="font-size:16px;"><b>To reduce customer churn, telecom companies need to predict which customers are at high risk of churn.</b></span>
#
# <span style="font-size:16px;"> To detect early signs of potential churn, one must first develop a holistic view of the customers and their interactions across numerous channels, including store/branch visits, product purchase histories, customer service calls, Web-based transactions, and social media interactions, to mention a few. </span>
#
# <span style="font-size:16px;">As a result, by addressing churn, these businesses may not only preserve their market position, but also grow and thrive. More customers they have in their network, the lower the cost of initiation and the larger the profit. As a result, the company's key focus for success is reducing client attrition and implementing effective retention strategy. </span>
# <a id="reduce"></a>
#
# <a id = "4" ></a>
# #### <b> Objectives</b>
# I will explore the data and try to answer some questions like:
# * What's the % of Churn Customers and customers that keep in with the active services?
# * Is there any patterns in Churn Customers based on the gender?
# * Is there any patterns/preference in Churn Customers based on the type of service provided?
# * What's the most profitable service types?
# * Which features and services are most profitable?
# * Many more questions that will arise during the analysis
# <a id="objective"></a>

# %% [markdown]
# ___

# %% [markdown]
# <a id = "5" ></a>
# # <span style="font-family:serif; font-size:28px;"> 2. Loading libraries and data</span>
# <a id="loading"></a>

# %%
import pandas as pd
import numpy as np
import missingno as msno
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import warnings
warnings.filterwarnings('ignore')

# %%
#loading data
df = pd.read_csv("/kaggle/input/telecom-dataset/telco.csv")
df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %% [markdown]
# ____________

# %% [markdown]
# <a id = "6" ></a>
# # <span style="font-family:serif; font-size:28px;"> 3. Understanding the data</span>
# <a id = "Understanding the data" ></a>

# %% [markdown]
# Each row represents a customer, each column contains customer’s attributes described on the column Metadata.

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %% [markdown]
# **The data set includes information about:**
# * **Customers who left within the last month** – the column is called Churn
#
# * **Services that each customer has signed up for** – phone, multiple lines, internet, online security, online backup, device protection, tech support, and streaming TV and movies
#
# * **Customer account information** - how long they’ve been a customer, contract, payment method, paperless billing, monthly charges, and total charges
#
# * **Demographic info about customers** – gender, age range, and if they have partners and dependents

# %%
df.shape
# Out:
# (7043, 21)

# %% [markdown]
# **7043 Rows and 21 Columns**

# %%
df.columns.values
# Out:
# array(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
#        'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract',
#        'PaperlessBilling', 'PaymentMethod', 'MonthlyCharges',
#        'TotalCharges', 'Churn'], dtype=object)

# %% [markdown]
# <a id = "7" ></a>
# # <span style="font-family:serif; font-size:28px;"> 4. Visualize missing values</span>
# <a id = "Visualize missing values" ></a>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %% [markdown]
# 1. No NULL values can be seen from this dataset overview
# 2. Checking the Data Types of each columns
# 3. The target we will use to guide the exploration is Churn

# %% [markdown]
# **Visualizing Missing Values as a Matrix**

# %%
msno.matrix(df);

# %% [markdown]
# * Using this matrix we can very quickly find the pattern of missingness in the dataset.
# * From the above visualisation we can observe that it has no peculiar pattern that stands out. In fact there is no missing data.
# * Alternatively, we can also find the sum of NULL values, as shown below

# %%
df.isna().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %% [markdown]
# * So, we see that there are no NULL values in any of the columns of the dataset

# %% [markdown]
# <a id = "8" ></a>
# # <span style="font-family:serif; font-size:28px;"> 5. Data Manipulation </span>
# <a id = "8" ></a>

# %%
df = df.drop(['customerID'], axis = 1)
#here axis =1, singnifies that 'customerID' is a column, default is axis=0 which denotes the rows, 
#but here we are to delete a column so we have to mention axis=1
df.head()
# Out:
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  Female              0     Yes         No       1           No
# 1    Male              0      No         No      34          Yes
# 2    Male              0      No         No       2          Yes
# 3    Male              0      No         No      45           No
# 4  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
# ...

# %% [markdown]
# * On deep analysis, we can find some indirect missingness in our data (which can be in form of blankspaces). Let's see that!

# %%
df['TotalCharges'] = pd.to_numeric(df.TotalCharges, errors='coerce')
df.isnull().sum()
# Out:
# gender               0
# SeniorCitizen        0
# Partner              0
# Dependents           0
# tenure               0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# MonthlyCharges       0
# TotalCharges        11
# Churn                0
# dtype: int64

# %% [markdown]
# We can see that Total Charges column has 11 NULL values after we converted that column to Numeric type. errors = 'coerce', sets the Invalid parsing as Nan. Lets check the rows where Total Charges is NaN

# %%
df[np.isnan(df['TotalCharges'])]
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 488   Female              0     Yes        Yes       0           No
# 753     Male              0      No        Yes       0          Yes
# 936   Female              0     Yes        Yes       0          Yes
# 1082    Male              0     Yes        Yes       0          Yes
# 1340  Female              0     Yes        Yes       0           No
# 3331    Male              0     Yes        Yes       0          Yes
# 3826    Male              0     Yes        Yes       0          Yes
# 4380  Female              0     Yes        Yes       0          Yes
# 5218    Male              0     Yes        Yes       0          Yes
# 6670  Female              0     Yes        Yes       0          Yes
# 6754    Male              0      No        Yes       0          Yes
#
#          MultipleLines InternetService       OnlineSecurity  \
# 488   No phone service             DSL                  Yes
# ...

# %% [markdown]
# * It can also be noted that the Tenure column is 0 for these entries even though the MonthlyCharges column is not empty.
# * Let's see if there are any other 0 values in the tenure column.

# %%
df[df['tenure'] == 0].index
# Out:
# Index([488, 753, 936, 1082, 1340, 3331, 3826, 4380, 5218, 6670, 6754], dtype='int64')

# %% [markdown]
# * If we notice, then these index numbers are exactly same to the row indexes of the above table, where each of these rows has Tenure = 0
# * There are no additional missing values in the Tenure column.
# * Let's delete the rows with missing values in Tenure column since there are only 11 rows and deleting them will not affect the data.

# %%
df.drop(labels=df[df['tenure'] == 0].index, axis=0, inplace=True)
df[df['tenure'] == 0].index
# Out:
# Index([], dtype='int64')

# %% [markdown]
# * Blank Index[] array shows that there are no rows now in which the Tenure column is 0
# * To solve the problem of missing values in TotalCharges column, I decided to fill it with the mean of TotalCharges values.

# %%
df.fillna(df["TotalCharges"].mean())
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0     Female              0     Yes         No       1           No
# 1       Male              0      No         No      34          Yes
# 2       Male              0      No         No       2          Yes
# 3       Male              0      No         No      45           No
# 4     Female              0      No         No       2          Yes
# ...      ...            ...     ...        ...     ...          ...
# 7038    Male              0     Yes        Yes      24          Yes
# 7039  Female              0     Yes        Yes      72          Yes
# 7040  Female              0     Yes        Yes      11           No
# 7041    Male              1     Yes         No       4          Yes
# 7042    Male              0      No         No      66          Yes
#
#          MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0     No phone service             DSL             No          Yes
# ...

# %% [markdown]
# * Checking for null values

# %%
df.isnull().sum()
# Out:
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %% [markdown]
# * Mapping Senior Citizen =1 to YES and Senior Citizen = 0 to NO

# %%
df["SeniorCitizen"]= df["SeniorCitizen"].map({0: "No", 1: "Yes"})
df.head()
# Out:
#    gender SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  Female            No     Yes         No       1           No
# 1    Male            No      No         No      34          Yes
# 2    Male            No      No         No       2          Yes
# 3    Male            No      No         No      45           No
# 4  Female            No      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
# ...

# %%
df.InternetService.unique()
# Out:
# array(['DSL', 'Fiber optic', 'No'], dtype=object)

# %%
df["InternetService"].describe(include=['object', 'bool'])
# Out:
# count            7032
# unique              3
# top       Fiber optic
# freq             3096
# Name: InternetService, dtype: object

# %%
numerical_cols = ['tenure', 'MonthlyCharges', 'TotalCharges']
df[numerical_cols].describe()
# Out:
#             tenure  MonthlyCharges  TotalCharges
# count  7032.000000     7032.000000   7032.000000
# mean     32.421786       64.798208   2283.300441
# std      24.545260       30.085974   2266.771362
# min       1.000000       18.250000     18.800000
# 25%       9.000000       35.587500    401.450000
# 50%      29.000000       70.350000   1397.475000
# 75%      55.000000       89.862500   3794.737500
# max      72.000000      118.750000   8684.800000

# %% [markdown]
# ___________

# %% [markdown]
# <a id = "9" ></a>
# # <span style="font-family:serif; font-size:28px;"> 6. Data Visualization </span>
# <a id = "9" ></a>

# %%
g_labels = ['Male', 'Female']
c_labels = ['No', 'Yes']
# Create subplots: use 'domain' type for Pie subplot
fig = make_subplots(rows=1, cols=2, specs=[[{'type':'domain'}, {'type':'domain'}]])
fig.add_trace(go.Pie(labels=g_labels, values=df['gender'].value_counts(), name="Gender"),
              1, 1)
fig.add_trace(go.Pie(labels=c_labels, values=df['Churn'].value_counts(), name="Churn"),
              1, 2)

# Use `hole` to create a donut-like pie chart
fig.update_traces(hole=.4, hoverinfo="label+percent+name+value", textfont_size=16)

fig.update_layout(
    title_text="Gender and Churn Distributions",
    # Add annotations in the center of the donut pies.
    annotations=[dict(text='Gender', x=0.19, y=0.5, font_size=20, showarrow=False),
                 dict(text='Churn', x=0.81, y=0.5, font_size=20, showarrow=False)])
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.27.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# ...

# %% [markdown]
# * 26.6% i.e. 1869 Customers switched to other firm.
# * 49.5% i.e. 3483 Customers are Females
# * 50.5% i.e. 3549 Customers are Males

# %% [markdown]
# Counting customers, and their gender bifucation

# %%
df["Churn"][df["Churn"]=="No"].groupby(by=df["gender"]).count()
# Out:
# gender
# Female    2544
# Male      2619
# Name: Churn, dtype: int64

# %% [markdown]
# * 2544+2619 = 5163, which is equal to the number of Customers who have stayed, Churn = No.

# %%
df["Churn"][df["Churn"]=="Yes"].groupby(by=df["gender"]).count()
# Out:
# gender
# Female    939
# Male      930
# Name: Churn, dtype: int64

# %% [markdown]
# * 939+930 = 1869, which is equal to the number of customers who went to other firms. Churn = Yes

# %%
plt.figure(figsize=(6, 6))
labels =["Churn: Yes","Churn:No"]
values = [1869,5163]
labels_gender = ["F","M","F","M"]
sizes_gender = [939,930 , 2544,2619]
colors = ['#FAAE7B', '#CD8C79']
colors_gender = ['#9F6976','#714674', '#9F6976','#714674']
explode = (0.3,0.3) 
explode_gender = (0.1,0.1,0.1,0.1)
textprops = {"fontsize":15}
#Plot
plt.pie(values, labels=labels,autopct='%1.1f%%',pctdistance=1.08, labeldistance=0.8,colors=colors, startangle=90,frame=True, explode=explode,radius=10, textprops =textprops, counterclock = True, )
plt.pie(sizes_gender,labels=labels_gender,colors=colors_gender,startangle=90, explode=explode_gender,radius=7, textprops =textprops, counterclock = True, )
#Draw circle
centre_circle = plt.Circle((0,0),5,color='black', fc='white',linewidth=0)
fig = plt.gcf()
fig.gca().add_artist(centre_circle)

plt.title('Churn Distribution w.r.t Gender: Male(M), Female(F)', fontsize=15, y=1.1)

# show plot 
 
plt.axis('equal')
plt.tight_layout()
plt.show()

# %% [markdown]
# * There is negligible difference in customer percentage/ count who chnaged the service provider. Both genders behaved in similar fashion when it comes to migrating to another service provider/firm.

# %%
df.Contract.unique()
# Out:
# array(['Month-to-month', 'One year', 'Two year'], dtype=object)

# %% [markdown]
# * There are three types of Contracts, lets see their distribution

# %%
color_map = {"Month-to-month": "#432371", "One year": "#FAAE7B", "Two year": "#9F6976"}
fig = px.histogram(df, x="Churn", color="Contract", barmode="group", title="<b>Customer contract distribution<b>", color_discrete_map=color_map)
fig.update_layout(width=700, height=500, bargap=0.1)
fig.show()
# Out:
# <div>                            <div id="7bdbde74-7c4c-4009-b98a-daa7ce29f0a1" class="plotly-graph-div" style="height:500px; width:700px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7bdbde74-7c4c-4009-b98a-daa7ce29f0a1")) {                    Plotly.newPlot(                        "7bdbde74-7c4c-4009-b98a-daa7ce29f0a1",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Contract=Month-to-month\u003cbr\u003eChurn=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Month-to-month","marker":{"color":"#432371","pattern":{"shape":""}},"name":"Month-to-month","offsetgroup":"Month-to-month","orientation":"v","showlegend":true,"x":["No","Yes","Yes","Yes","No","No","Yes","No","Yes","No","Yes","No","Yes","Yes","No","No","Yes","Yes","Yes","No","No","
# ...

# %% [markdown]
# * About 75% of customers with Month-to-Month Contract opted to move out as compared to 13% of customrs with One Year Contract and 3% with Two Year Contract

# %%
labels = df['PaymentMethod'].unique()
values = df['PaymentMethod'].value_counts()
#color_map = {"Electronic check": "#432371", "Mailed check": "#FAAE7B", "Bank transfer (automatic)": "#9F6976", "Credit card (automatic)":"#714674"}
fig = go.Figure(data=[go.Pie(labels=labels, values=values, hole=.3)])
fig.update_layout(title_text="<b>Payment Method Distribution</b>")
fig.show()
# Out:
# <div>                            <div id="51b40561-b3fe-4d69-8b4f-b24dc811ade9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("51b40561-b3fe-4d69-8b4f-b24dc811ade9")) {                    Plotly.newPlot(                        "51b40561-b3fe-4d69-8b4f-b24dc811ade9",                        [{"hole":0.3,"labels":["Electronic check","Mailed check","Bank transfer (automatic)","Credit card (automatic)"],"values":[2365,1604,1542,1521],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556
# ...

# %%
color_map = {"Electronic check": "#432371", "Mailed check": "#FAAE7B", "Bank transfer (automatic)": "#9F6976", "Credit card (automatic)":"#714674"}
fig = px.histogram(df, x="Churn", color="PaymentMethod", title="<b>Customer Payment Method distribution w.r.t. Churn</b>",
                   color_discrete_map=color_map)
fig.update_layout(width=700, height=500, bargap=0.1)
fig.show()
# Out:
# <div>                            <div id="aa44eb4d-a30f-4185-a150-f05cfd537230" class="plotly-graph-div" style="height:500px; width:700px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("aa44eb4d-a30f-4185-a150-f05cfd537230")) {                    Plotly.newPlot(                        "aa44eb4d-a30f-4185-a150-f05cfd537230",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"PaymentMethod=Electronic check\u003cbr\u003eChurn=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Electronic check","marker":{"color":"#432371","pattern":{"shape":""}},"name":"Electronic check","offsetgroup":"Electronic check","orientation":"v","showlegend":true,"x":["No","Yes","Yes","Yes","No","No","Yes","Yes","Yes","Yes","Yes","No","No","Yes","No","Yes","No","No","Yes
# ...

# %% [markdown]
# * Major customers who moved out were having Electronic Check as Payment Method.
# * Customers who opted for Credit-Card automatic transfer or Bank Automatic Transfer and Mailed Check as Payment Method were less likely to move out.

# %%
df["InternetService"].unique()
# Out:
# array(['DSL', 'Fiber optic', 'No'], dtype=object)

# %% [markdown]
# * Checking the Unique Internet Service Providers

# %% [markdown]
# If the Customer is Male, then no of customers in each Internet service provider category, along with their Churn distribution.

# %%
 df[df["gender"]=="Male"][["InternetService", "Churn"]].value_counts()
# Out:
# InternetService  Churn
# DSL              No       992
# Fiber optic      No       910
# No               No       717
# Fiber optic      Yes      633
# DSL              Yes      240
# No               Yes       57
# Name: count, dtype: int64

# %% [markdown]
# If the Customer is Female, then no of customers in each Internet service provider category, along with their Churn distribution.

# %%
df[df["gender"]=="Female"][["InternetService", "Churn"]].value_counts()
# Out:
# InternetService  Churn
# DSL              No       965
# Fiber optic      No       889
# No               No       690
# Fiber optic      Yes      664
# DSL              Yes      219
# No               Yes       56
# Name: count, dtype: int64

# %%
fig = go.Figure()
#color_map = {"DSL": "#432371", "Fiber Optic": "#FAAE7B", "No internet": "#9F6976"}
fig.add_trace(go.Bar(
  x = [['Churn:No', 'Churn:No', 'Churn:Yes', 'Churn:Yes'],
       ["Female", "Male", "Female", "Male"]],
  y = [965, 992, 219, 240],
  name = 'DSL',
))

fig.add_trace(go.Bar(
  x = [['Churn:No', 'Churn:No', 'Churn:Yes', 'Churn:Yes'],
       ["Female", "Male", "Female", "Male"]],
  y = [889, 910, 664, 633],
  name = 'Fiber optic',
))

fig.add_trace(go.Bar(
  x = [['Churn:No', 'Churn:No', 'Churn:Yes', 'Churn:Yes'],
       ["Female", "Male", "Female", "Male"]],
  y = [690, 717, 56, 57],
  name = 'No Internet',
))

fig.update_layout(title_text="<b>Churn Distribution w.r.t. Internet Service and Gender</b>")

fig.show()
# Out:
# <div>                            <div id="848b8f4d-8674-4a0d-a01b-be7af0e744f9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("848b8f4d-8674-4a0d-a01b-be7af0e744f9")) {                    Plotly.newPlot(                        "848b8f4d-8674-4a0d-a01b-be7af0e744f9",                        [{"name":"DSL","x":[["Churn:No","Churn:No","Churn:Yes","Churn:Yes"],["Female","Male","Female","Male"]],"y":[965,992,219,240],"type":"bar"},{"name":"Fiber optic","x":[["Churn:No","Churn:No","Churn:Yes","Churn:Yes"],["Female","Male","Female","Male"]],"y":[889,910,664,633],"type":"bar"},{"name":"No Internet","x":[["Churn:No","Churn:No","Churn:Yes","Churn:Yes"],["Female","Male","Female","Male"]],"y":[690,717,56,57],"type":"bar"}],                        {"template":{"
# ...

# %% [markdown]
# * A lot of customers choose the Fiber optic service and it's also evident that the customers who use Fiber optic have high churn rate, this might suggest a dissatisfaction with this type of internet service.
# * Customers having DSL service are majority in number and have less churn rate compared to Fibre optic service.

# %%
color_map = {"Yes": "#432371", "No": "#FAAE7B"}
fig = px.histogram(df, x="Churn", color="Dependents", barmode="group", title="<b>Dependents distribution</b>", color_discrete_map=color_map)
fig.update_layout(width=700, height=500, bargap=0.1)
fig.show()
# Out:
# <div>                            <div id="45970742-fdaf-4807-9047-ceb216e8c64a" class="plotly-graph-div" style="height:500px; width:700px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("45970742-fdaf-4807-9047-ceb216e8c64a")) {                    Plotly.newPlot(                        "45970742-fdaf-4807-9047-ceb216e8c64a",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Dependents=No\u003cbr\u003eChurn=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"No","marker":{"color":"#FAAE7B","pattern":{"shape":""}},"name":"No","offsetgroup":"No","orientation":"v","showlegend":true,"x":["No","No","Yes","No","Yes","Yes","No","Yes","No","No","Yes","No","No","No","Yes","No","Yes","No","No","No","No","No","No","No","Yes","No","Yes","Yes","No","No","No
# ...

# %% [markdown]
# * Customers without dependants are more likely to churn

# %%
color_map = {"Yes": "#432371", "No": "#FAAE7B"}
fig = px.histogram(df, x="Churn", color="Partner", barmode="group", title="<b>Chrun distribution w.r.t. Partners</b>", color_discrete_map=color_map)
fig.update_layout(width=700, height=500, bargap=0.1)
fig.show()
# Out:
# <div>                            <div id="1f11e714-3157-4c32-875c-f7872cd4fc48" class="plotly-graph-div" style="height:500px; width:700px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1f11e714-3157-4c32-875c-f7872cd4fc48")) {                    Plotly.newPlot(                        "1f11e714-3157-4c32-875c-f7872cd4fc48",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Partner=Yes\u003cbr\u003eChurn=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Yes","marker":{"color":"#432371","pattern":{"shape":""}},"name":"Yes","offsetgroup":"Yes","orientation":"v","showlegend":true,"x":["No","Yes","No","No","No","Yes","No","No","No","Yes","Yes","No","No","No","No","No","No","No","No","No","No","No","Yes","No","No","No","No","No","No","No","No","N
# ...

# %% [markdown]
# * Customers without Partners are more likely to churn

# %%
color_map = {"Yes": "#432371", "No": "#FAAE7B"}
fig = px.histogram(df, x="Churn", color="SeniorCitizen", title="<b>Chrun distribution w.r.t. Senior Citizen</b>", color_discrete_map=color_map)
fig.update_layout(width=700, height=500, bargap=0.1)
fig.show()
# Out:
# <div>                            <div id="d5ed45d4-e3b2-4b73-aacb-618bad58454f" class="plotly-graph-div" style="height:500px; width:700px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d5ed45d4-e3b2-4b73-aacb-618bad58454f")) {                    Plotly.newPlot(                        "d5ed45d4-e3b2-4b73-aacb-618bad58454f",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"SeniorCitizen=No\u003cbr\u003eChurn=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"No","marker":{"color":"#FAAE7B","pattern":{"shape":""}},"name":"No","offsetgroup":"No","orientation":"v","showlegend":true,"x":["No","No","Yes","No","Yes","Yes","No","No","Yes","No","No","No","No","Yes","No","No","No","No","Yes","No","No","Yes","No","No","No","Yes","Yes","No","Yes","No",
# ...

# %% [markdown]
# * Customers below 60 years of age are more likely to churn.
# * Senior Citizens are less likely to churn

# %%
color_map = {"Yes": "#432371", "No": "#FAAE7B", "No internet service": "#9F6976"}
fig = px.histogram(df, x="Churn", color="OnlineSecurity", barmode="group", title="<b>Churn w.r.t Online Security</b>", color_discrete_map=color_map)
fig.update_layout(width=700, height=500, bargap=0.1)
fig.show()
# Out:
# <div>                            <div id="1bac5d1d-551d-45c4-bb08-c1a165334d50" class="plotly-graph-div" style="height:500px; width:700px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1bac5d1d-551d-45c4-bb08-c1a165334d50")) {                    Plotly.newPlot(                        "1bac5d1d-551d-45c4-bb08-c1a165334d50",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"OnlineSecurity=No\u003cbr\u003eChurn=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"No","marker":{"color":"#FAAE7B","pattern":{"shape":""}},"name":"No","offsetgroup":"No","orientation":"v","showlegend":true,"x":["No","Yes","Yes","No","Yes","No","Yes","Yes","No","Yes","No","Yes","Yes","Yes","No","No","Yes","No","Yes","Yes","No","No","No","Yes","No","Yes","Yes","No","No"
# ...

# %% [markdown]
# * Customers with No Online Security have churned more.
# * But most of the customers who have No Online Security have stayed back too.

# %%
color_map = {"Yes": '#432371', "No": '#FAAE7B'}
fig = px.histogram(df, x="Churn", color="PaperlessBilling",  title="<b>Chrun distribution w.r.t. Paperless Billing</b>", color_discrete_map=color_map)
fig.update_layout(width=700, height=500, bargap=0.1)
fig.show()
# Out:
# <div>                            <div id="dd46dc7a-765d-475c-b206-82ff15e8f20b" class="plotly-graph-div" style="height:500px; width:700px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dd46dc7a-765d-475c-b206-82ff15e8f20b")) {                    Plotly.newPlot(                        "dd46dc7a-765d-475c-b206-82ff15e8f20b",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"PaperlessBilling=Yes\u003cbr\u003eChurn=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Yes","marker":{"color":"#432371","pattern":{"shape":""}},"name":"Yes","offsetgroup":"Yes","orientation":"v","showlegend":true,"x":["No","Yes","Yes","Yes","No","Yes","No","Yes","No","No","Yes","No","No","Yes","No","Yes","No","No","Yes","No","Yes","Yes","No","No","No","No","Yes","No","
# ...

# %% [markdown]
# * Customers who opted for Paperless Billing have churned more.

# %%
color_map = {"Yes": "#432371", "No": "#FAAE7B", "No internet service": "#9F6976"}
fig = px.histogram(df, x="Churn", color="TechSupport",barmode="group",  title="<b>Chrun distribution w.r.t. TechSupport</b>",
                   color_discrete_map=color_map)
fig.update_layout(width=700, height=500, bargap=0.1)
fig.show()
# Out:
# <div>                            <div id="e5902b7d-007f-4d76-8786-78c76bc353ef" class="plotly-graph-div" style="height:500px; width:700px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e5902b7d-007f-4d76-8786-78c76bc353ef")) {                    Plotly.newPlot(                        "e5902b7d-007f-4d76-8786-78c76bc353ef",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"TechSupport=No\u003cbr\u003eChurn=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"No","marker":{"color":"#FAAE7B","pattern":{"shape":""}},"name":"No","offsetgroup":"No","orientation":"v","showlegend":true,"x":["No","No","Yes","Yes","Yes","No","No","No","No","No","Yes","No","No","Yes","No","Yes","Yes","Yes","No","No","Yes","No","Yes","Yes","No","No","No","No","Yes","No",
# ...

# %% [markdown]
# * Customers with No Tech Support,are most likely to migrate to another Service Provider.
# * They might have not got their complaints heared.

# %%
color_map = {"Yes": '#432371', "No": '#FAAE7B'}
fig = px.histogram(df, x="Churn", color="PhoneService", title="<b>Chrun distribution w.r.t. Phone Service</b>", color_discrete_map=color_map)
fig.update_layout(width=700, height=500, bargap=0.1)
fig.show()
# Out:
# <div>                            <div id="9b6a619d-fdf6-489d-9f05-4ce5632cd423" class="plotly-graph-div" style="height:500px; width:700px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9b6a619d-fdf6-489d-9f05-4ce5632cd423")) {                    Plotly.newPlot(                        "9b6a619d-fdf6-489d-9f05-4ce5632cd423",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"PhoneService=No\u003cbr\u003eChurn=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"No","marker":{"color":"#FAAE7B","pattern":{"shape":""}},"name":"No","offsetgroup":"No","orientation":"v","showlegend":true,"x":["No","No","No","Yes","Yes","No","No","No","No","No","No","No","No","No","Yes","Yes","Yes","Yes","Yes","No","No","No","No","No","No","No","No","Yes","No","No","Ye
# ...

# %% [markdown]
# * Most Customers availing Phone Service have migrated to another Service Provider among those who have churned.
# * Very small fraction of Customers have No Phone service and out of those only about 1/3rd are likely to churn.

# %%
sns.set_context("paper",font_scale=1.1)
ax = sns.kdeplot(df.MonthlyCharges[(df["Churn"] == 'No') ],
                color="#FAAE7B", shade = True);
ax = sns.kdeplot(df.MonthlyCharges[(df["Churn"] == 'Yes') ],
                 ax =ax,color="#432371", shade= True);
ax.legend(["Not Churn","Churn"],loc='upper right');
ax.set_ylabel('Density');
ax.set_xlabel('Monthly Charges');
ax.set_title('Distribution of monthly charges by churn');

# %% [markdown]
# * Customers with higher monthly charges are more likely to churn, with less Monthly charges, the fraction of customers likely to churn is less.

# %%
ax = sns.kdeplot(df.TotalCharges[(df["Churn"] == 'No') ],
                color="#FAAE7B", shade = True);
ax = sns.kdeplot(df.TotalCharges[(df["Churn"] == 'Yes') ],
                ax =ax, color="#432371", shade= True);
ax.legend(["Not Churn","Churn"],loc='upper right');
ax.set_ylabel('Density');
ax.set_xlabel('Total Charges');
ax.set_title('Distribution of total charges by Churn');

# %% [markdown]
# * If the Total Charges are more then the Customers are likely not to go to another Service Providers, which probably shows a trust of customers if the price is more, then the service provided will be better.

# %%
fig = px.box(df, x='Churn', y = 'tenure')

# Update yaxis properties
fig.update_yaxes(title_text='Tenure (Months)', row=1, col=1)
# Update xaxis properties
fig.update_xaxes(title_text='Churn', row=1, col=1)

# Update size and title
fig.update_layout(autosize=True, width=750, height=600,
    title_font=dict(size=25, family='Courier'),
    title='<b>Tenure vs Churn</b>',
)

fig.show()
# Out:
# <div>                            <div id="e199c408-9f0b-4757-b805-6cdfe8d5a801" class="plotly-graph-div" style="height:600px; width:750px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e199c408-9f0b-4757-b805-6cdfe8d5a801")) {                    Plotly.newPlot(                        "e199c408-9f0b-4757-b805-6cdfe8d5a801",                        [{"alignmentgroup":"True","hovertemplate":"Churn=%{x}\u003cbr\u003etenure=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x":["No","No","Yes","No","Yes","Yes","No","No","Yes","No","No","No","No","Yes","No","No","No","No","Yes","No","Yes","No","Yes","No","No","No","Yes","Yes","No","Yes","No","No","No","No","No","No","Yes","No","Yes","Yes","N
# ...

# %% [markdown]
# * Long Term Customers are less likely to Churn as compared to the new customers.

# %%
plt.figure(figsize=(25, 10))

corr = df.apply(lambda x: pd.factorize(x)[0]).corr()

mask = np.triu(np.ones_like(corr, dtype=bool))

ax = sns.heatmap(corr, mask=mask, xticklabels=corr.columns, yticklabels=corr.columns, annot=True, linewidths=.2, cmap='PuOr', vmin=-1, vmax=1)

# %% [markdown]
# * From the above plotted heatmap we can infer that the higher intensity of Blue color signifies higher churn rate.
# * The higher intensity of Yellow color, signifies lesser churn rate
# * And the remainng neutral color shades signifies the customers who are not availing any services so do not fall in either of the Churn or Not Churn categories.

# %% [markdown]
# __________________

# %% [markdown]
# <a id = "10" ></a>
# # <span style="font-family:serif; font-size:28px;"> 7. Conclusion </span>
# <a id = "10" ></a>

# %% [markdown]
# Here, we come to an end of my Data Analysis.Customer churn is definitely bad to a firm ’s profitability. Various strategies can be implemented to eliminate customer churn. The best way to avoid customer churn is for a company to truly know its customers. This includes identifying customers who are at risk of churning and working to improve their satisfaction. My above analysis, has identified the category of the Customers and the risk factors involved which leads to customer churn. Improving customer service is, of course, at the top of the priority for tackling this issue. Building customer loyalty through relevant experiences and specialized service is another strategy to reduce customer churn. Some firms survey customers who have already churned to understand their reasons for leaving in order to adopt a proactive approach to avoiding future customer churn. This Data analysis acts as a survey in order to help the organisation better its facilities keeping in mind the risk factors which are mostly the areas where they are lagging behind.

# %% [markdown]
# <span style="color:blue;font-family:serif; font-size:20px;">  Please upvote if you liked the kernel!
#     <p style="color:red;font-family:serif; font-size:20px;">KEEP KAGGLING!</p>
# </span>
